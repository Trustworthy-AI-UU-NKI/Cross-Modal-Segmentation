# %%
lpips_CTT_MRIF = np.array([0.5694543123245239, 0.4862534701824188, 0.4753663241863251, 0.4752363860607147, 0.5191863775253296, 0.5142139196395874, 0.5160680413246155, 0.5101048946380615, 0.5207816362380981, 0.5048760175704956, 0.5087862610816956, 0.5193678736686707, 0.5297470688819885, 0.5258827805519104, 0.5233023762702942, 0.5328691601753235, 0.53272545337677, 0.5354732275009155, 0.5336849093437195, 0.5236397385597229, 0.5295184254646301, 0.5355080366134644])
lpips_MRIT_CTF = np.array([0.6346412897109985, 0.5787134766578674, 0.5861579775810242, 0.5428651571273804, 0.5569751858711243, 0.5517659187316895, 0.5629323124885559, 0.549083948135376, 0.5473728775978088, 0.5535270571708679, 0.5452046990394592, 0.5311957597732544, 0.5369945168495178, 0.548798143863678, 0.5404890775680542, 0.5462395548820496, 0.5455403923988342, 0.5306204557418823, 0.5336428284645081, 0.5380920767784119, 0.5413398742675781, 0.5422106385231018])

# %%
lpips_CTT_MRIF2 = np.array([0.4728068709373474, 0.376814603805542, 0.3738752603530884, 0.36978304386138916, 0.4009458124637604, 0.40893879532814026, 0.40468496084213257, 0.40359264612197876, 0.3900602459907532, 0.37047845125198364, 0.38191455602645874, 0.3825548589229584, 0.388647198677063, 0.3847781717777252, 0.3812304139137268, 0.39013123512268066, 0.39046260714530945, 0.389360636472702, 0.38963988423347473, 0.38754481077194214, 0.3889662027359009, 0.38771072030067444])
lpips_MRIT_CTF2 = np.array([0.5948960185050964, 0.5268118977546692, 0.5487608909606934, 0.47487354278564453, 0.48192068934440613, 0.4601826071739197, 0.46659329533576965, 0.45215144753456116, 0.44206884503364563, 0.44616395235061646, 0.44779282808303833, 0.4103441536426544, 0.41230008006095886, 0.41448864340782166, 0.41160017251968384, 0.4182204604148865, 0.4162902235984802, 0.3994273543357849, 0.3995042145252228, 0.4119960367679596, 0.40685176849365234, 0.405987411737442])

# %%
print(len(lpips_CTT_MRIF))
print(len(lpips_MRIT_CTF))
# Out:
# 22
# 22

# %%
print(len(lpips_MRI))
print(len(lpips_CT))
print(len(kid_MRI))
print(len(kid_CT))
print(len(ssim_CTT_MRIF))
print(len(ssim_MRIT_CTF))
print(len(x))
# Out:
# 22
# 22
# 22
# 22
# 22
# 22
# 22

# %%
# create a plt plot for each metric
fig, ax = plt.subplots(2, 2, figsize=(15,10))
#fig.suptitle('Quality Metrics', fontsize=16)
ax[0, 0].set_title('LPIPS within domain')
#ax[0, 0].set_xlabel('Model Epoch')
ax[0, 0].plot(x, lpips_MRI, label='MRI')
ax[0, 0].plot(x, lpips_CT, label='CT')
ax[0, 0].legend()
ax[0, 1].set_title('KID')
#ax[0, 1].set_xlabel('Model Epoch')
ax[0, 1].plot(x, kid_MRI, label='MRI')
ax[0, 1].plot(x, kid_CT, label='CT')
ax[0, 1].legend()
ax[1, 0].set_title('SSIM')
ax[1, 0].set_xlabel('Model Epoch')
ax[1, 0].plot(x, ssim_CTT_MRIF, label='CTT_MRIF')
ax[1, 0].plot(x, ssim_MRIT_CTF, label='MRIT_CTF')
ax[1, 0].legend()
#ax[1, 1].set_title('LPIPS ALEX')
ax[1, 1].set_title('LPIPS between domain')
ax[1, 1].set_xlabel('Model Epoch')
ax[1, 1].plot(x, lpips_CTT_MRIF, label='CTT_MRIF')
ax[1, 1].plot(x, lpips_MRIT_CTF, label='MRIT_CTF')
ax[1, 1].legend()

# %%
index_max_SSM_CTT_MRIF = np.argmax(ssim_CTT_MRIF)
index_max_SSM_MRIT_CTF = np.argmax(ssim_MRIT_CTF)
# min or max?
index_min_lpips_MRI = np.argmin(lpips_MRI)
index_min_lpips_CT = np.argmin(lpips_CT)
index_min_kid_MRI = np.argmin(kid_MRI)
index_min_kid_CT = np.argmin(kid_CT)
index_min_lpips_CTT_MRIF = np.argmin(lpips_CTT_MRIF)
index_min_lpips_MRIT_CTF = np.argmin(lpips_MRIT_CTF)


print("CT is target domain")
print("path where SSM_MRIT_CTF is max: ", x[index_max_SSM_MRIT_CTF])
print("path where LPIPS_CT is min: ", x[index_min_lpips_CT])
print("path where KID_CT is min: ", x[index_min_kid_CT])
print("path where LPIPS_MRIT_CTF is min: ", x[index_min_lpips_MRIT_CTF])
print("path where squeeze LPIPS_MRIT_CTF is min: ", x[np.argmin(lpips_MRIT_CTF2)])


print("\nMRI is target domain")
print("path where SSM_CTT_MRIF is max: ", x[index_max_SSM_CTT_MRIF])
print("path where LPIPS_MRI is min: ", x[index_min_lpips_MRI])
print("path where KID_MRI is min: ", x[index_min_kid_MRI])
print("path where LPIPS_CTT_MRIF is min: ", x[index_min_lpips_CTT_MRIF])
print("path where squeeze LPIPS_CTT_MRIF is min: ", x[np.argmin(lpips_CTT_MRIF2)])
# Out:
# CT is target domain
# path where SSM_MRIT_CTF is max:  599
# path where LPIPS_CT is min:  1099
# path where KID_CT is min:  1049
# path where LPIPS_MRIT_CTF is min:  899
# path where squeeze LPIPS_MRIT_CTF is min:  899
#
# MRI is target domain
# path where SSM_CTT_MRIF is max:  199
# path where LPIPS_MRI is min:  1099
# path where KID_MRI is min:  1099
# path where LPIPS_CTT_MRIF is min:  199
# path where squeeze LPIPS_CTT_MRIF is min:  199
